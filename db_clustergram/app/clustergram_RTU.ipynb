# %% [markdown]
# # **2D (XY) Clustergram** with Python-Plotly interactive graphing <br> *using the gene expression dataset*
# ## Learn more about Clastergram Chart:
# - https://plotly.com/python/clustergram/
# - https://dash.plotly.com/dash-bio/clustergram
#
# *To run all cells in this notebook, please use `Run`, then `Run All Cells` options in the top menu. Alternatively, you can press ▶ button above or `ctrl + enter/return` on each cell separately. To modify the content of the cell:*
# * *use single-click on the code-like cell*
# * *use double-click on the text-like cell*
#
# Color variables in **Plotly** have a string type value provided in the one of the following forms:
# - HEX color, e.g., "#FFFFFF"
# - HSL color, e.g., "hsl(hue, saturation,lightness)"; The Hue values are in degrees, from 0 to 360 (0 - red, 120 - green, 240 - blue). The saturation and lightness are in % from 0% to 100%.
# - RGB color, e.g., "rgb(red, green, blue)"; Each channel is provided as an intiger between 0 and 255, e.g., rgb(128, 0, 128).
# - RGBA color, e.g., "rgba(r, g, b, a)" with 'a' value set up in range from 0.0 (transparent) to 1.0 (solid)
# - common name, e.g., "blue"
#
# **Built-in Plotly colors** *(common names)*
#
# <span style="background-color:aliceblue">aliceblue</span>,
# <span style="background-color:antiquewhite">antiquewhite</span>,
# <span style="background-color:aqua">aqua</span>,
# <span style="background-color:aquamarine">aquamarine</span>,
# <span style="background-color:azure">azure</span>,
# <span style="background-color:beige">beige</span>,
# <span style="background-color:bisque">bisque</span>,
# <span style="background-color:black; color: white">black</span>,
# <span style="background-color:blanchedalmond">blanchedalmond</span>,
# <span style="background-color:blue">blue</span>,
# <span style="background-color:blueviolet">blueviolet</span>,
# <span style="background-color:brown">brown</span>,
# <span style="background-color:burlywood">burlywood</span>,
# <span style="background-color:cadetblue">cadetblue</span>,
# <span style="background-color:chartreuse">chartreuse</span>,
# <span style="background-color:chocolate">chocolate</span>,
# <span style="background-color:coral">coral</span>,
# <span style="background-color:cornflowerblue">cornflowerblue</span>,
# <span style="background-color:cornsilk">cornsilk</span>,
# <span style="background-color:crimson">crimson</span>,
# <span style="background-color:cyan">cyan</span>,
# <span style="background-color:darkblue">darkblue</span>,
# <span style="background-color:darkcyan">darkcyan</span>,
# <span style="background-color:darkgoldenrod">darkgoldenrod</span>,
# <span style="background-color:darkgray">darkgray</span>,
# <span style="background-color:darkgrey">darkgrey</span>,
# <span style="background-color:darkgreen">darkgreen</span>,
# <span style="background-color:darkkhaki">darkkhaki</span>,
# <span style="background-color:darkmagenta">darkmagenta</span>,
# <span style="background-color:darkolivegreen">darkolivegreen</span>,
# <span style="background-color:darkorange">darkorange</span>,
# <span style="background-color:darkorchid">darkorchid</span>,
# <span style="background-color:darkred">darkred</span>,
# <span style="background-color:darksalmon">darksalmon</span>,
# <span style="background-color:darkseagreen">darkseagreen</span>,
# <span style="background-color:darkslateblue">darkslateblue</span>,
# <span style="background-color:darkslategray">darkslategray</span>,
# <span style="background-color:darkslategrey">darkslategrey</span>,
# <span style="background-color:darkturquoise">darkturquoise</span>,
# <span style="background-color:darkviolet">darkviolet</span>,
# <span style="background-color:deeppink">deeppink</span>,
# <span style="background-color:deepskyblue">deepskyblue</span>,
# <span style="background-color:dimgray">dimgray</span>,
# <span style="background-color:dimgrey">dimgrey</span>,
# <span style="background-color:dodgerblue">dodgerblue</span>,
# <span style="background-color:firebrick">firebrick</span>,
# <span style="background-color:floralwhite">floralwhite</span>,
# <span style="background-color:forestgreen">forestgreen</span>,
# <span style="background-color:fuchsia">fuchsia</span>,
# <span style="background-color:gainsboro">gainsboro</span>,
# <span style="background-color:ghostwhite">ghostwhite</span>,
# <span style="background-color:gold">gold</span>,
# <span style="background-color:goldenrod">goldenrod</span>,
# <span style="background-color:gray">gray</span>,
# <span style="background-color:grey">grey</span>,
# <span style="background-color:green">green</span>,
# <span style="background-color:greenyellow">greenyellow</span>,
# <span style="background-color:honeydew">honeydew</span>,
# <span style="background-color:hotpink">hotpink</span>,
# <span style="background-color:indianred">indianred</span>,
# <span style="background-color:indigo">indigo</span>,
# <span style="background-color:ivory">ivory</span>,
# <span style="background-color:khaki">khaki</span>,
# <span style="background-color:lavender">lavender</span>,
# <span style="background-color:lavenderblush">lavenderblush</span>,
# <span style="background-color:lawngreen">lawngreen</span>,
# <span style="background-color:lemonchiffon">lemonchiffon</span>,
# <span style="background-color:lightblue">lightblue</span>,
# <span style="background-color:lightcoral">lightcoral</span>,
# <span style="background-color:lightcyan">lightcyan</span>,
# <span style="background-color:lightgoldenrodyellow">lightgoldenrodyellow</span>,
# <span style="background-color:lightgray">lightgray</span>,
# <span style="background-color:lightgrey">lightgrey</span>,
# <span style="background-color:lightgreen">lightgreen</span>,
# <span style="background-color:lightpink">lightpink</span>,
# <span style="background-color:lightsalmon">lightsalmon</span>,
# <span style="background-color:lightseagreen">lightseagreen</span>,
# <span style="background-color:lightskyblue">lightskyblue</span>,
# <span style="background-color:lightslategray">lightslategray</span>,
# <span style="background-color:lightslategrey">lightslategrey</span>,
# <span style="background-color:lightsteelblue">lightsteelblue</span>,
# <span style="background-color:lightyellow">lightyellow</span>,
# <span style="background-color:lime">lime</span>,
# <span style="background-color:limegreen">limegreen</span>,
# <span style="background-color:linen">linen</span>,
# <span style="background-color:magenta">magenta</span>,
# <span style="background-color:maroon">maroon</span>,
# <span style="background-color:mediumaquamarine">mediumaquamarine</span>,
# <span style="background-color:ediumblue">ediumblue</span>,
# <span style="background-color:mediumorchid">mediumorchid</span>,
# <span style="background-color:mediumpurple">mediumpurple</span>,
# <span style="background-color:mediumseagreen">mediumseagreen</span>,
# <span style="background-color:mediumslateblue">mediumslateblue</span>,
# <span style="background-color:mediumspringgreen">mediumspringgreen</span>,
# <span style="background-color:mediumturquoise">mediumturquoise</span>,
# <span style="background-color:mediumvioletred">mediumvioletred</span>,
# <span style="background-color:midnightblue">midnightblue</span>,
# <span style="background-color:mintcream">mintcream</span>,
# <span style="background-color:mistyrose">mistyrose</span>,
# <span style="background-color:moccasin">moccasin</span>,
# <span style="background-color:navajowhite">navajowhite</span>,
# <span style="background-color:navy">navy</span>,
# <span style="background-color:oldlace">oldlace</span>,
# <span style="background-color:olive">olive</span>,
# <span style="background-color:olivedrab">olivedrab</span>,
# <span style="background-color:orange">orange</span>,
# <span style="background-color:orangered">orangered</span>,
# <span style="background-color:orchid">orchid</span>,
# <span style="background-color:palegoldenrod">palegoldenrod</span>,
# <span style="background-color:palegreen">palegreen</span>,
# <span style="background-color:paleturquoise">paleturquoise</span>,
# <span style="background-color:palevioletred">palevioletred</span>,
# <span style="background-color:papayawhip">papayawhip</span>,
# <span style="background-color:peachpuff">peachpuff</span>,
# <span style="background-color:peru">peru</span>,
# <span style="background-color:pink">pink</span>,
# <span style="background-color:plum">plum</span>,
# <span style="background-color:powderblue">powderblue</span>,
# <span style="background-color:purple">purple</span>,
# <span style="background-color:red">red</span>,
# <span style="background-color:rosybrown">rosybrown</span>,
# <span style="background-color:royalblue">royalblue</span>,
# <span style="background-color:rebeccapurple">rebeccapurple</span>,
# <span style="background-color:saddlebrown">saddlebrown</span>,
# <span style="background-color:salmon">salmon</span>,
# <span style="background-color:sandybrown">sandybrown</span>,
# <span style="background-color:seagreen">seagreen</span>,
# <span style="background-color:seashell">seashell</span>,
# <span style="background-color:sienna">sienna</span>,
# <span style="background-color:silver">silver</span>,
# <span style="background-color:skyblue">skyblue</span>,
# <span style="background-color:slateblue">slateblue</span>,
# <span style="background-color:slategray">slategray</span>,
# <span style="background-color:slategrey">slategrey</span>,
# <span style="background-color:snow">snow</span>,
# <span style="background-color:springgreen">springgreen</span>,
# <span style="background-color:steelblue">steelblue</span>,
# <span style="background-color:tan">tan</span>,
# <span style="background-color:teal">teal</span>,
# <span style="background-color:thistle">thistle</span>,
# <span style="background-color:tomato">tomato</span>,
# <span style="background-color:turquoise">turquoise</span>,
# <span style="background-color:violet">violet</span>,
# <span style="background-color:wheat">wheat</span>,
# <span style="background-color:white">white</span>,
# <span style="background-color:whitesmoke">whitesmoke</span>,
# <span style="background-color:yellow">yellow</span>,
# <span style="background-color:yellowgreen">yellowgreen</span>
#
#
# **Built-in Plotly colorscales**
# Select one of the following named colorscales for coloring the Heatmap section:
#
# 'aggrnyl', 'agsunset', 'algae', 'amp', 'armyrose', 'balance',
# 'blackbody', 'bluered', 'blues', 'blugrn', 'bluyl', 'brbg',
# 'brwnyl', 'bugn', 'bupu', 'burg', 'burgyl', 'cividis', 'curl',
# 'darkmint', 'deep', 'delta', 'dense', 'earth', 'edge', 'electric',
# 'emrld', 'fall', 'geyser', 'gnbu', 'gray', 'greens', 'greys',
# 'haline', 'hot', 'hsv', 'ice', 'icefire', 'inferno', 'jet',
# 'magenta', 'magma', 'matter', 'mint', 'mrybm', 'mygbm', 'oranges',
# 'orrd', 'oryel', 'oxy', 'peach', 'phase', 'picnic', 'pinkyl',
# 'piyg', 'plasma', 'plotly3', 'portland', 'prgn', 'pubu', 'pubugn',
# 'puor', 'purd', 'purp', 'purples', 'purpor', 'rainbow', 'rdbu',
# 'rdgy', 'rdpu', 'rdylbu', 'rdylgn', 'redor', 'reds', 'solar',
# 'spectral', 'speed', 'sunset', 'sunsetdark', 'teal', 'tealgrn',
# 'tealrose', 'tempo', 'temps', 'thermal', 'tropic', 'turbid',
# 'turbo', 'twilight', 'viridis', 'ylgn', 'ylgnbu', 'ylorbr', 'ylorrd'
#
# *Appending '_r' to a named colorscale reverses it.*
#
# You can also create your own colorscale as an array of lists, each composed of two elements. The first refers to the percentile rank, and the second to the applied color. Color can be provided in any string format among hex, hsl, rgb, or common name.
# <br>e.g.,
# <br>**custom_colorscale = [[0.0, '#636EFA'], [0.25, '#AB63FA'], [0.5, '#FFFFFF'], [0.75, '#E763FA'], [1.0, '#EF553B']]**
#
#
# Uncomment the following code cell and run it to display a preview for the built-in Plotly colorscales.

# %%
#import plotly.express as px
#plotly_colors = px.colors.sequential.swatches_continuous()
#plotly_colors.show()

# %% [markdown]
# ## 0. Imports

# %%
import os
import flask
import numpy as np
import pandas as pd
import json
from urllib import request

import dash
from dash import html, dcc
from dash.dependencies import Input, Output, State
from dash.exceptions import PreventUpdate
from dash.dash import no_update
import dash_bootstrap_components as dbc
import dash_bio as db

# %%
# input file
#file_path = os.getcwd()       # [string] provide string path to the input file, os.getcwd() takes current path
file_path = "/Users/abadacz/REPOS/GIF/data_graphing/db_clustergram/data"
filename = "input.csv"        # [string] input file name
col_separator = ','           # [string] type of the column separator in the input file: '\t' for tabulator, ' ' for space, ',' for comma, etc.

input_path = file_path
df = pd.read_csv(str(input_path+"/"+filename).replace('//','/'), sep=col_separator)

# %%
def generate_html_label(text):
    return html.Label(children=str(text), style=css_lab1)

# %% [markdown]
# ## 1. CSS styles

# %%
color1 = '#D6F2FA'    # light blue *
color2 = '#738fab'    # middle teal
color3 = '#008CBA'    # dark teal *
color4 = '#006699'    # darkest teal
color5 = ''
css_div = {'display':'inline-block'}
css_lpd = {**css_div, 'height':'95vh', 'padding':'5px', 'background-color':color1, 'border-right': '1px solid #008CBA'}
css_rpd = {**css_div, 'flex-grow': '1', 'background-color':'ghostwhite'}
css_btn = {'font-size':'20px', 'background-color':color3, 'color':'white', 'border-radius':'8px', 'border':'1px solid #006B88', 'marginBottom':'10px'}
css_lab = {'font-style':'italic', 'display':'block', 'margin-top':'5px'}
css_lab1 = {**css_lab, 'color':color3, 'font-size':'16px'}
css_lab2 = {**css_lab, 'color':color2, 'font-size':'12px'}
css_inp = {'marginBottom':'10px', 'width':'60%', 'display':'inline-block', 'font-size':'14px', 'padding':'6px 0'}
#css_val = {'width':'30%', 'marginBottom':'20px'}
#css_rad = {'padding': '1vh 2.5vw 0 0'}
#css_col = {'display':'inline-block', 'width':'8%', 'padding':'3px 3px 3px 3px', 'font-size':'12px'}

css_upload_box = {'background-color': '#f9f9f9', 'width': '25vw', 'min-height': '60px', 'height': '20vh', 'border-width': '2px', 'border-color':color4, 'border-style': 'dashed', 'border-radius': '5px', 'display': 'table-cell', 'vertical-align': 'middle', 'text-align': 'center'}

# %% [markdown]
# ## 2. App layout

# %%
# Layout components
opts1 = [
  html.Label('from file system: ', id='custom-label', style=css_lab2),
  dcc.Upload(id='upload-box',
    children=html.Div([html.P('drag & drop', style={'color':color2}), html.P('or click to browse', style={'color':color2})]),
    className='upload-box',
    style=css_upload_box,
    max_size=-1,
    multiple=True),
  html.Label('from online resources: ', id='custom-url-label', style=css_lab2),
  dcc.Input(id="custom-url", type="url", placeholder="enter URL", value='', debounce=False),
  dbc.Button("download", id="download-btn", n_clicks=0, size="sm", outline=True, color="secondary", className="me-1 align-top", style={'marginLeft':'1vw', 'width':'25%'}),
  html.P(''),
  html.Label(id="settings-upload-label", style=css_lab1),
  html.Div(id="settings-upload-inputs", className="mt-3")
]

opts = html.Div([
  dbc.Accordion([
    dbc.AccordionItem(
      opts1,
      title="A. UPLOAD INPUTS",
      item_id="item-1",
    ),
    dbc.AccordionItem(
      "This is the content of the second section",
      title="Item 2",
      item_id="item-2",
    ),
    dbc.AccordionItem(
      "This is the content of the third section",
      title="Item 3",
      item_id="item-3",
    ),
  ], id="accordion", start_collapsed=True, always_open=True, flush=False, style={'width':'25vw'}),
  html.Div(id="accordion-contents", className="mt-3"),
], id='optionsDiv')

# %%
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.scripts.config.serve_locally=True
app.css.config.serve_locally=True

app.css.append_css({'external_url':'/Users/abadacz/REPOS/GIF/data_graphing/_assets/css/stylesheet.css'})

#@app.server.route('/static/<path:path>')
#def static_file(path):
#    static_folder = os.path.join(os.getcwd(), 'static')
#    return send_from_directory(static_folder, path)

# %%
app.layout = html.Div([
  html.Link(href='stylesheet.css', rel='stylesheet'),
  # STORAGE
  dcc.Store(id="custom-box-files", data='', storage_type='session'),
  dcc.Store(id="custom-url-files", data='', storage_type='session'),
  dcc.Store(id="user-files-list", data='', storage_type='session'),

  # OPTIONS
  html.Div([
    html.Button('Show Options', id='options', n_clicks=0, style=css_btn),
    opts,    
  ], id='left-panelDiv', style=css_lpd),

  # GRAPH
  html.Div([
#    db.Clustergram(data=df),
#    db.Ideogram(id='dashbio-ideogram',),
  ], id='graph-panelDiv', style=css_rpd)

], id='app', style={'display': 'flex'})

# %% [markdown]
# ## 3. Javascript clientside callbacks

# %%
# open-close options section
app.clientside_callback(
    """
    function(largeValue1, largeValue2) {
        var x = document.getElementById("optionsDiv");
        var y = document.getElementById("options");
        var z = document.getElementById("left-panelDiv");
        if (x.style.display === "none") {
            x.style.display = "block";
            y.style.backgroundColor = "#D6F2FA";
            y.style.color = "#90B6C1";
            y.innerText = "✕";
            z.width = "25vw";
        } else {
            x.style.display = "none";
            y.style.backgroundColor = "#008CBA";
            y.style.color = "white";
            y.innerText = "≡";
            z.width = "2.1%";
        }
    }
    """,
    Output('optionsDiv', 'style'),
    Input('options', 'n_clicks'),
)

# %% [markdown]
# ## 4. Callbacks responsive to changes in Dash widgets (options panel)

# %%
# 
@app.callback(
    Output("accordion-contents", "children"),
    [Input("accordion-options", "active_item")],
)
def change_item(item):
    return f"Item selected: {item}"

# The function returns updated dictionary of filename:file_content for all user-loaded files via upload-box
@app.callback(Output('custom-box-files', 'data'),
              [Input('upload-box', 'filename'), Input('upload-box', 'contents')],
              State('custom-box-files', 'data'), prevent_initial_call = True)
def upload_files_box(names, contents, files):
    if names is not None:
        if files == '':
            files = {i:contents[num] for num,i in enumerate(names)}
        else:
            files = json.loads(files)
            for num,i in enumerate(names):
                files[i] = contents[num]
        return json.dumps(files)

# The function returns updated dictionary of filename:file_content for all user-loaded files via online-url
@app.callback(Output('custom-url-files', 'data'),
              [Input('download-btn', 'n_clicks')],
              [State('custom-url', 'value'), State('custom-url-files', 'data')], prevent_initial_call = True)
def upload_files_url(download, url, files):
    if url != '':
        filename = url.strip().split('/')[-1]
        try:
            with request.urlopen(url) as f:
                content = f.read().decode('utf-8')
            if files == '':
                files = {}
                files[filename] = content
            else:
                files = json.loads(files)
                files[filename] = content
            return json.dumps(files)
        except:
            pass
    else:
        raise PreventUpdate

# The function creates a list of user-loaded files that can be used for plotting
@app.callback(Output('user-files-list', 'data'),
             [Input('custom-box-files', 'data'), Input('custom-url-files', 'data')], prevent_initial_call = True)
def create_list_of_custom_files(files_box, files_url):
    files = []
    for i in [files_box, files_url]:
        if i != '':
            files.extend(list(json.loads(i).keys()))
    return files

# Display summary of settings
@app.callback(
    [Output("settings-upload-label", "children"), Output("settings-upload-inputs", "children")],
    [Input("user-files-list", "data")])
def display_inputs_settings(loaded_files):
    if loaded_files == '':
        return["Please load inputs using available options.", '']
    else:
        info = "The following files were loaded: "
        return [info, [generate_html_label(i) for i in loaded_files]]

# %% [markdown]
# ## 5. Run server

# %%
app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# /Users/abadacz/Library/Miniforge3_x86/envs/graphing/lib/python3.9/site-packages/dash/resources.py:63: UserWarning: You have set your config to `serve_locally=True` but A local version of /Users/abadacz/REPOS/GIF/data_graphing/_assets/css/stylesheet.css is not available.
# If you added this file with `app.scripts.append_script` or `app.css.append_css`, use `external_scripts` or `external_stylesheets` instead.
# See https://dash.plotly.com/external-resources
#   warnings.warn(
# 127.0.0.1 - - [13/Dec/2022 17:36:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Dec/2022 17:36:17] "GET /_dash-component-suites/dash/dcc/async-upload.js HTTP/1.1" 304 -
# ...

# %% [markdown]
# ## 1. Set up global variables
# You can easily adjust the overall styling of the chart by setting up the global variables.

# %%
# input file
file_path = os.getcwd()       # [string] provide string path to the input file, os.getcwd() takes current path
filename = "input.csv"        # [string] input file name
col_separator = ','           # [string] type of the column separator in the input file: '\t' for tabulator, ' ' for space, ',' for comma, etc.
class_labs = []               # [list] (optional) list of labels for additional category; should match the number of data columns in the input file;

# initial data parsing and clustering (to generate data for dendrograms)
log_transform = False         # [boolean] if True, ransform the data by taking the base-two logarithm of all values in the dataset
standardize = 'none'          # [string] default = 'none'; dimension for standardizing values: 'none', 'row', 'column'; with standardization, the mean is 0 and the standard deviation is 1;
cluster = 'all'               # [string] default = 'all'; dimension along which the data will be clustered: 'row', 'column', or 'all';
row_dist = 'euclidean'        # [string] default = 'euclidean'; distance metric for rows: braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’, ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulsinski’, ‘kulczynski1’, ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’ (works when using scipy.spatial.distance.pdist()) 
col_dist = 'euclidean'        # [string] default = 'euclidean'; distance metric for columns: braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’, ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulsinski’, ‘kulczynski1’, ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’ (works when using scipy.spatial.distance.pdist()) 
link_method = 'complete'      # [string] default = 'complete'; linkage algorithm to use: 'complete', 'average', 'weighted' and 'ward' (nearest-neighbors chain), or 'single' (optimized minimum spanning)

######- interactive graph : DENDROGRAM section(s) -######
leaf_order = True             # [boolean] determine leaf order that maximizes similarity between neighboring leaves
dendro_ratio = [0.15, 0.3]    # [list] list of two float elements providing proportions of heatmap vs. dendrogram sections; scale ratio of [X axis dendrogram, Y axis dendrogram] with respect to the size of the heatmap
dendro_factor = 0.9           # [float] scale ratio between dendrogram and cluster bars sections
dendro_line_width = [2, 2]    # [list] line width [row, column] for the dendrograms
dendro_threshold = {'row': 3, 'col': 3}   # maximum linkage value for which unique colors are assigned to clusters
dendro_colors = {'row': ['#636EFA', '#00CC96', '#19D3F3'], 'col': ['#AB63FA', '#EF553B'], 'bg': '#506784'}      # list of colors to use for different clusters in the dendrogram that have a root under the threshold for each dimension 
row_prefix = 'protein cluster' # custom name of the row dendrogram clusters
col_prefix = 'sample cluster'  # custom name of the column dendrogram clusters
list_all_row = True           # [boolean] on interactive labels for Y dendrogram list all elements in the given cluster
n_per_line_row = 5            # [int] number of elements names listed per single line on interactive labels for Y dendrogram (prevents overly wide labels )

######- interactive graph : GROUP/CLASS BARS -###### 
row_markers = [{'group': 98, 'annotation': 'description for cluster 98', 'color': 'white'}, {'group': 75, 'annotation': 'description for cluster 75', 'color': '#009dd1'}, {'group': 1, 'annotation': 'description for cluster 1', 'color': 'white'}]    # bars for selected row (Y) clusters; 'white' for 'color' will use by default the corresponding color from dendrogram; use <br> tag within annotation to break the string into multiple lines; 
col_markers = [{'group': 1, 'annotation': 'description for cluster 1', 'color': 'white'}, {'group': 2, 'annotation': 'description for cluster 2', 'color': 'yellowgreen'}, {'group': 6, 'annotation': 'description for cluster 6', 'color': 'white'}]       # bars for selected column (X) clusters; 'white' for 'color' will use by default the corresponding color from dendrogram; use <br> tag within annotation to break the string into multiple lines; 


######- interactive graph : HEATMAP SECTION -######
# - HEATMAP GENERAL SETTINGS
center_values = True          # [boolean] if True, center the values of the heatmap about zero
display_cutoff = 2            # [int] standardized values below the negative of this value will be colored with one shade, and the values that are above this value will be colored with another
color_map = 'rdbu'            # colorscale for the heatmap; use built-in Plotly colorscale (list provided on the top of this notebook) or define your own colorscale

# - HEATMAP COLORBAR SETTINGS
show_colorbar = True                     # [boolean] if True, the colorbar (heatmap colorscale) will be displayed;
colorbar_len = 1 - dendro_ratio[0]       # [float] vertical length of the colorbar; default = 1 - dendro_ratio[0], means that the colorbar height matches the heatmap height
colorbar_x = 1.04                        # [float] horizontal position of the colorbar; value above 1 places colorbar on the right margin of the plotting area
colorbar_y = 0.5*(1 - dendro_ratio[0])   # [float] vertical position of the center of the colorbar; default = 0.5*(1-dendro_ratio[0]), means that the colorbar will be aligned vertically with the heatmap 

# - HEATMAP X AXIS SETTINGS
#.... X axis title
x_title = "X: Sample identifier"         # [string] text of X axis title
x_ti_color = "black"                     # [string] color of X axis title
x_ti_size = 20                           # [int] color of X axis title

#.... X axis line (graph border)
x_axis_show = True            # [boolean] if True the X axis is visible, if False X axis is hidden
x_axis_mirror = False         # [boolean] if True the X axis complementary mirror axis is visible (on the top/bottom of the graph)
x_axis_width = 1              # [int] width of X axis line
x_axis_color = "black"        # [string] color of X axis line

#.... X axis ticks' labels
show_xtick_lab = True         # [string] if True the labels of X axis ticks are visible
xtick_labs = []               # [list] list of strings with ticks' labels for X axis; should match the number of data columns in the input file; if empty list, the keys (columns' names) from the header will be used
x_tick_lab_side = 'bottom'    # [string] side of the graph where the ticks and labels will apear; enter "top" or 'bottom'
x_tick_lab_angle = 45         # [int] angle of X axis ticks in range 0 - 360
x_tick_lab_size = 14          # [int] font size of ticks labels for X axis (size must correspond to the list of tickvals) 
x_tick_lab_color = "black"    # [string] font color of ticks labels for X axis 

#.... X axis ticks (marks)
x_axis_ticks = "outside"      # [string] position of X axis ticks: "outside", "inside", "" (not visible)
x_tick_width = 1              # [int] width (in px) of X axis ticks
x_tick_len = 5                # [int] length (in px) of X axis ticks
x_tick_color = 'black'        # [string] color of X axis ticks

# - HEATMAP Y AXIS SETTINGS
#.... Y axis title
y_title = "Y: Protein UniProt ID"      # [string] custom title for Y axis
y_ti_color = "black"                   # [string] color for Y axis title
y_ti_size = 20                         # [int] color for Y axis title
y_ti_x = 1.24                          # [float] Y axis title horizontal position; balow 0 - left side of the graph, above 1 - right side of the graph
y_ti_y = 0.42                          # [float] Y axis title vertical position; usually value around 0.5 center title with the heatmap
y_ti_angle = 90                        # [float] the angle of the text: 0 is horizontal; -90 is vertical-left; 90 is vertical-right

#.... Y axis line (graph border)
y_axis_show = True            # [boolean] if True the Y axis is visible, if False Y axis is hidden
y_axis_mirror = False         # boolean] if True the X axis complementary mirror axis is visible (on the left/right of the graph)
y_axis_width = 1              # [int] width of Y axis line
y_axis_color = "black"        # [string] color of Y axis line

#.... Y axis ticks' labels
show_ytick_lab = True         # [string] if True the labels of Y axis ticks are visible
y_tick_lab_side = 'right'     # [string] side of the graph where the ticks and labels will apear; enter "left" or 'right'
y_tick_lab_angle = 0          # [int] angle of Y axis ticks in range 0 - 360
y_tick_lab_size = 12          # [int] font size of ticks labels for Y axis (size must correspond to the list of tickvals) 
y_tick_lab_color = "black"    # [string] font color of ticks labels for Y axis 

y_ticks_str = True            # [boolean] if True, text labels for the Y axis in the heatmap section can be dispalyed; otherwise an automatic numerical (data index) values will be dispalyed;
y_col_name = 'label'          # [string] name of the column in the input used for labeling ticks on the Y-axis for the heatmap section; requires: y_ticks_str = True
y_nticks = 10                 # [int] number of ticks on the zoomed Y axis with text ticks' labels; requires: y_ticks_str = True
y_zoom = [0,1]                # [range] specify the zoomed fragment along normalized Y axis; 0 - bottom, 1 - top; requires: y_ticks_str = True; text labels switches off the interactive Y axis zooming - this variable can zoom the Y axis though; 

#.... Y axis ticks (marks)
y_axis_ticks = "outside"      # [string] position of Y axis ticks: "outside", "inside", "" (not visible)
y_tick_width = 1              # [int] width (in px) of Y axis ticks
y_tick_len = 5                # [int] length (in px) of Y axis ticks
y_tick_color = 'black'        # [string] color of Y axis ticks


# - HEATMAP ON-HOVER INTERACTIVE LABELS
heatmap_name = 'heatmap'      # [string] custom name displayed on the interactive labels for the heatmap points
h_label_x = 'sample'          # [string] label for X data displayed on the interactive label; by default the ticks of X axis will be used as data; 'none' will switch off the option 
h_label_y = 'UniProt ID'      # [string] label for Y data displayed on the interactive label; by default the ticks of Y axis will be used as data; 'none' will switch off the option 
h_label_z = 'value'           # [string] label for Z data displayed on the interactive label; by default the heatmap (Z) values will be used as data; 'none' will switch off the option 
h_label_4 = 'none'            # ['none' or list] optional 4-element list [label, dimension, data, file]; label element is any string; dimension is a string: 'x', 'y', 'z' specyfing the data structure; data is an array (1D for 'x' or 'y', 2D for 'z') provided explicitly or as a string of the column name from the input file; provide file name if other than 'filename' variable
h_label_5 = 'none'            # ['none' or list] optional 4-element list [label, dimension, data, file]; label element is any string; dimension is a string: 'x', 'y', 'z' specyfing the data structure; data is an array (1D for 'x' or 'y', 2D for 'z') provided explicitly or as a string of the column name from the input file; provide file name if other than 'filename' variable
#ex# h_label_4 = ['x index', 'x', [str(i+1) for i in range(10)], '']    # example usage: add numerical index for samples on X axis (X dimension); use range(n) where n is a number of columns on your heatmap
#ex# h_label_4 = ['custom y', 'y', y_col_name, '']                      # example usage: add lables stored in the selected column (Y dimension) in the input file; here the column name is provided via pre-defined variable
#ex# h_label_4 = ['unique z', 'z', '', 'external_file.csv']             # example usage: add unique description for each XY point; use data stored in the other file of dimensions corresponding to the Heatmap input file (same number of columns and rows)


######- EXPORT SETTINGS -######

# interactive graph - on-hover labels
hover_align = "auto"          # [string] horizontal alignment of the text content within hover label box: "left", "right", "auto"
hover_size = 14               # [int] font size of interactive labels

# interactive graph - general layout settings
graph_height = 600            # [int] height of an interactive graph
graph_width = 800             # [int] width of an interactive graph
margins = [0,'d',350,'d']       # [list] int values for graph margins in order [left, top, right, bottom]; default = 'd'
graph_bg_color = "white"      # [string] background color in the plottiong area e.g., common color name, rgb(r,g,b), "#FFFFFF")
drawing_bg_color = "white"    # [string] background color of the drawing (e.g., common color name, rgb(r,g,b), "#FFFFFF")
html_auto = False             # [boolean] if True the generated interactive HTML graph will automatically open in a separate tab in the web browser

# interactive graph - title & legend settings
graph_title = "Clustergram Plot"        # [string] provide custom title for Graph title
font_family = "Arial"                   # [string] font family: "Arial", "Balto", "Courier New", "Droid Sans",, "Droid Serif", "Droid Sans Mono", "Gravitas One", "Old Standard TT", "Open Sans", "Overpass", "PT Sans Narrow", "Raleway", "Times New Roman"
ti_color = "black"                      # [string] graph title color (e.g., common color name: "blue", rgb: rgb(0,0,0), hex: "#FFFFFF")
ti_size = 24                            # [int] graph title font size
ti_x = 0.38                             # [float] graph title horizontal position
ti_y = 0.9                              # [float] graph title vertical position
is_legend = True                        # [boolean] if True the legend is visible, if False the legend is hidden
legend_x = 1.4
legend_y = 1

# static image export settings
static_img_format = 'png'                      # [string] format of exported static image: png, svg, jpeg, webp, pdf, eps
static_img_filename = 'example_clustergram'    # [string] provide custom filename for exported static image
static_img_height = 1200                       # [int] enter the expected height (in px) of exported static image 
static_img_width = 800                         # [int] enter the expected width (in px) of exported static image 
static_img_scale = 1                           # [int] enter the expected scale ratio of exported static image 

print(filename)

# %% [markdown]
# ## 2. Load input file(s)
# Read and load data into object-like DataFrame data structure with *Pandas*
# * input file: *input.csv* &emsp; &emsp; # the input file in this example is "," separated
# * input path: *`input_path=os.getcwd()`* &emsp; &emsp; # finds the path to the current directory <br>
#     *<span style="color:gray">If your input is in the children-directory of the current folder you can easily append the remaining part of the path: <br>`path=os.getcwd()+'/INPUTS'`, and if it is on a completely different path, then give the full path.</span>*
# * dataframe: *`df=pd.DataFrame()`* &emsp; &emsp; # object like data structure created with pandas library
#     * *`pd.read_csv(filename, sep=",")`* &emsp; # reads column-type text file, default separator is comma

# %%
input_path = file_path
df = pd.read_csv(str(input_path+"/"+filename).replace('//','/'), sep=col_separator)

# %% [markdown]
# ### 2a.(optional) Preview your data structure
#
# * *`print(df)`* &emsp; # displays the top...bottom fragments of pandas *DataFrame* object
# * *`print(df.keys())`* &emsp; # displays the names of the columns<br>
#     <span style="color:gray">*DataFrame* keys are very important, because they are directly used to select the column(s) from which the data will be extracted to the chart.</span>

# %%
print("The keys in your DataFrame are: \n\n", df.keys().tolist(), "\n")
#print("There is a preview of your DataFrame: \n\n", df)

# %% [markdown]
# ### 3. (optional) Parse header row in the dataframe to adjust keys (column names)
# You can modyfiy the header row in the pandas dataframe to adjust column names (used as labels on X axis in the heatmap section) or create new useful variables.

# %%
if not xtick_labs:
    labels = list(df.columns.values)         # derive heder row
    labels.remove(y_col_name)                # remove key of the data labeling column
    xtick_labs = ['_'.join(lab.split('_')[:3]) for lab in labels]              # modify each key keeping relevant part of the string (primary classification category)
    if not class_labs:
        class_labs = [lab.split('_')[3].replace('.','_') for lab in labels]    # modify each key keeping the other part of the string (secondary classification category - optional)
    if h_label_5 == 'none':
        h_label_5 = ['sample class', 'x', class_labs, '']                      # use extracted data (secondary classification) on the interactive labels of the Heatmap section
#print("xtick_labs = ",xtick_labs)
#print("class_labs = ",class_labs)

# %% [markdown]
# ## 4. Create trace(s) for your graph
# In Plotly **trace** is a data series plotted as a particular type of graph. In this example we will use **clustergram** but there are many more predefined [trace types](https://plotly.com/python/reference/scatter/) in *Plotly*. <br>
# *<span style="color:gray">In general, complex graphs composed of many traces are more convenient to create using Graph Objects wrapper. You can find a suitable example in this repository.</span>*<br>
# In this example, we will create an interactive clustergram composed of many traces, including single 2D heatmap, two 1D dendrograms for X & Y axes, and bar charts for additional level of data classification.

# %%
fig, curves, traces = db.Clustergram(   # define Figure object composed of a heatmap with dendogram
    data=df,                            # provide source dataFrame
    column_labels=xtick_labs,           # list of labels for the heatmap X axis
    row_labels=list(df.index),          # list of numerical indices for the heatmap Y axis 
    generate_curves_dict = True,        # return a dictionary with the cluster number associated with each curve number in the graph; May be useful for capturing the cluster number that is clicked.
    return_computed_traces = True,      # return the precomputed dendrogram traces; May be useful if one wishes to add, e.g., group markers to the figure without recalculating the clustering in the entire figure.

    # data parsing and clustering
    log_transform = log_transform,      # if True, ransform the data by taking the base-two logarithm of all values in the dataset
    standardize = standardize,          # dimension for standardizing values: 'none', 'row', 'column'; with standardization, the mean is 0 and the standard deviation is 1;
    cluster = cluster,                  # dimension along which the data will be clustered: 'row', 'column', or 'all';
    row_dist = row_dist,                # distance metric for rows: braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’, ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulsinski’, ‘kulczynski1’, ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’ (scipy.spatial.distance.pdist()) 
    col_dist = col_dist,                # distance metric for columns: braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’, ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulsinski’, ‘kulczynski1’, ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’ (scipy.spatial.distance.pdist()) 
    link_method = link_method,          # linkage algorithm to use: 'complete', 'average', 'weighted' and 'ward' (nearest-neighbors chain), or 'single' (optimized minimum spanning)
#    dist_fun = scipy.spatial.distance.pdist,      # loaded default = scipy.spatial.distance.pdist (Note: when uncommented the import of scipy is needed); function to compute the pairwise distance from the observations
#    link_fun = scipy.cluster.hierarchy.linkage,   # loaded default = scipy.cluster.hierarchy.linkage (Note: when uncommented the import of scipy is needed); function to compute the linkage matrix from the pairwise distances

    # dendrograms
    optimal_leaf_order = leaf_order,    # determine leaf order that maximizes similarity between neighboring leaves
    display_ratio = dendro_ratio,       # dendrograms' heights [row, column] with respect to the size of the heatmap
    color_threshold = dendro_threshold, # maximum linkage value for which unique colors are assigned to clusters
    color_list = dendro_colors,         # list of colors to use for different clusters in the dendrogram that have a root under the threshold for each dimension 
    line_width = dendro_line_width,     # line width [row, column] for the dendrograms

    # classification bars
    row_group_marker = row_markers,     # annotations for row clusters 
    col_group_marker = col_markers,     # annotations for column clusters 
    annotation_font = {},               # font options for annotations

    # heatmap
    center_values = center_values,      # if True, center the values of the heatmap about zero
    display_range = display_cutoff,     # standardized values below the negative of this value will be colored with one shade, and the values that are above this value will be colored with another
    color_map = color_map,              # colorscale for the heatmap
    
    # other optional params
#    imputer_parameters = {'missing_values' : '', 'strategy' : '', 'axis' : ''}    # if needed, see https://scikit -learn.org/stable/modules/generated/sklearn.preprocessing.Imputer.html; 'axis=0' for columns, 'axis=1' for rows    
#    computed_traces = [],              # dendrogram traces from another (precomputed) Clustergram component    
#    row_colors = [],                   # list of row colors (observation colors)
#    row_colors_label = '',             # string which describes the annotation label for row_colors
#    column_colors = [],                # list of column colors (observation colors)
#    column_colors_label = '',          # string which describes the annotation label for column_colors
#    hidden_labels = [],                # optional list with elements 'row' and/or 'col' to hide corresponding labels on the final plot     
)

# %% [markdown]
# ## 4. Update config for built-in options for the interactivity
# At the top right of the interactive chart, when you hover over it, a manu appears with pre-built options for interactivity. By defining **config**, you can add or exclude certain options and make the chart even more customizable. In particular, *`modeBarButtonsToAdd`* allows you to add additional buttons with options that, for example, allow you to draw lines or shapes on the graph. This way you can highlight important points  or parts of the chart.

# %%
config = {
    'responsive': True, 'showTips': True,
    'modeBarButtonsToAdd':['drawline', 'drawopenpath', 'drawclosedpath', 'drawcircle', 'drawrect',
                           'eraseshape', 'resetViews', 'toggleHover', 'toggleSpikelines'], 
    'toImageButtonOptions': {
        'format': static_img_format,        # one of png, svg, jpeg, webp
        'filename': static_img_filename,    # enter the default name for static image available for download
        'height': static_img_height,        # dimensions of the exported static image can be different than for the chart available in this notebook
        'width': static_img_width,          
        'scale': static_img_scale,          # multiply font size for the title/legend/axis/canvas sizes by this factor
    }
}

# %% [markdown]
# ## 5. Update graph layout settings
# Figure object is composed of two components:
# * data
# * layout
#
# You can customize a number of **layout** elements by calling the *`update_layout()`* function. In this example, you can learn the most important attributes. However, there are many more, which you can learn in detail from the [Plotly documentation](https://plotly.com/python/reference/layout/).
#
# There are also other *update* functions, such as *`update_traces()`*, which allows you to modify the settings for a particular trace (**data**), especially if there are more than one in the chart. In this example, we have modified the point markers by adding a black border to the colored points and adjusting their size.
#
# <span style="color:gray">*Enjoy exploring interactivity in the graph.*</span>
# * <span style="color:gray">*Preview the annotation of a point with interactive labels that appear when you hover over the point.*</span>
# * <span style="color:gray">*Select a region of the graph to zoom in on it.*</span>
# * <span style="color:gray">*Manage the display of the data series by clicking on the 'state code' in the legend (on the right).*</span>
# * <span style="color:gray">*Use the options in the built-in mode bar at the top of the plotting area, to add additional objects to the chart.*</span>

# %%
# Adjust heatmap
xtick_vals = []
ytick_vals = []
ytick_labs = []
y_step = 1
x_range = []
row_clusters = {}
col_clusters = {}

for trace in fig["data"]:
    if trace.type == 'heatmap':
        yticks_dict = dict(zip(trace.y, list(df[y_col_name])))
        if y_ticks_str:            # prepare text labels for Y axis ticks 
            arr = np.asarray(list(yticks_dict.keys()))
            if y_zoom[0] == 0:
                y_zoom[0] = min(trace.y)
            else:
                val = round(y_zoom[0] * max(trace.y),1)
                y_zoom[0] = arr[(np.abs(arr - val)).argmin()]
            if y_zoom[1] == 1:
                y_zoom[1] = max(trace.y)
            else:
                val = round(y_zoom[1] * max(trace.y),1)
                y_zoom[1] = arr[(np.abs(arr - val)).argmin()]
            y_step = (y_zoom[1] - y_zoom[0])/y_nticks
            val = y_zoom[0]
            for i in range(0,y_nticks+1):
                z = arr[(np.abs(arr - val)).argmin()]
                ytick_vals.append(z)
                ytick_labs.append(yticks_dict[z])
                val += y_step
        else:                      # else, use numerical Y axis indices for ticks' labels
            y_step = trace.y[1] - trace.y[0]
            y_zoom = [min(trace.y) - y_step, max(trace.y) + y_step]
        x_step = (max(trace.x) - min(trace.x))/17
        x_range = [min(trace.x) - x_step, max(trace.x) + x_step]
        xtick_vals = trace.x
        # Adjust other attributes of the Heatmap section and used colorscale
        trace.xaxis = 'x1'
        trace.yaxis = 'y1'
        trace.showscale = show_colorbar
        trace.colorbar.len = colorbar_len 
        trace.colorbar.x = colorbar_x
        trace.colorbar.y = colorbar_y

        # adjust the content of the Heatmap interactive label
        trace.name = heatmap_name 
        if h_label_x != 'none' or h_label_x != '':
            trace.hovertemplate = h_label_x + ': %{x}<br>'
        if h_label_y != 'none' or h_label_y != '':
            trace.text = np.tile(list(df[y_col_name]), (len(trace.x), 1))
            trace.text = np.transpose(trace.text)
            trace.hovertemplate += h_label_y + ': %{text}<br>'
        if h_label_z != 'none' or h_label_z != '':
            trace.hovertemplate += h_label_z + ': %{z}<br>'
        for num, lab_var in enumerate([h_label_4, h_label_5]):
            if num == 0:
                attr = "hovertext"
            else:
                attr = "customdata"
            if lab_var != 'none':
                if isinstance(lab_var[2], str):                       # column name
                    if lab_var[3] != '' and lab_var[3] != 'none':   # data from external file
                        data_4 = pd.read_csv(str(lab_var[2]), sep=col_separator)[lab_var[2]]
                    else:
                        data_4 = df[lab_var[2]]
                else:
                    data_4 = lab_var[2]
                if lab_var[1] == 'z':
                    setattr(trace, attr, data_4)
                elif lab_var[1] == 'x':
                    setattr(trace, attr, np.tile(data_4, (len(trace.y), 1)))
                elif h_label_4[1] == 'y':
                    tmp = np.tile(data_4, (len(trace.x), 1))
                    setattr(trace, attr, np.transpose(tmp))
                trace.hovertemplate += lab_var[0] + ': %{'+attr+'}<br>' + '<extra><b>' + trace.name + '</b></extra>'
                
    # Derive data from generic dendrogram clusters (ranges, trace color)
    elif trace.type == 'scatter':
        if trace.name != None:
            if trace.name.startswith("Row"):
                trace.text = trace.name.replace('Row Cluster ', '').strip()                # stores cluster ID (index)
                row_clusters[trace.text] = [trace.y[0], trace.y[3], '', trace.marker['color'], trace.x[1]]
            elif trace.name.startswith("Col"):
                trace.text = trace.name.replace('Col Cluster ', '').strip()                # stores cluster ID (index)
                col_clusters[trace.text] = [trace.x[0], trace.x[3], '', trace.marker['color'], trace.y[1]]
print('Heatmap trace adjusted.')

# %%
# Adjust dendrogram traces and generate data about children clusters
for idx, trace in enumerate(fig["data"]):
    if trace.type == 'scatter':
        if trace.name != None:                 # dendrograms
            trace.hovertext = ''
            trace.hoverinfo = 'text + name'
            if trace.name.startswith("Row"):   # Y-dendrograms
                if row_prefix != '':
                    trace.name = trace.name.replace('Row Cluster', row_prefix).strip()         # custom prefix name for clusters
                trace.xaxis = 'x3'
                trace.yaxis = 'y1'
                if trace.y[0] in yticks_dict and trace.y[3] in yticks_dict:
                    trace.hovertext = str(yticks_dict[trace.y[0]]) + " and " + str(yticks_dict[trace.y[3]])
                    row_clusters[trace.text][2] = trace.hovertext.replace(' and', ',')
                else:
                    tmp = ''
                    for c in row_clusters:
                        if c != trace.text:
                            diff = row_clusters[c][1] - (row_clusters[c][1] - row_clusters[c][0])/2
                            if trace.y[3] == diff:   
                                trace.hovertext += "cluster " + c + " + "
                                if trace.y[0] in yticks_dict:
                                    tmp += str(yticks_dict[trace.y[0]]) + " + "
                            elif trace.y[0] == diff:
                                trace.hovertext += "cluster " + c + " + "
                                if trace.y[3] in yticks_dict:
                                    tmp += str(yticks_dict[trace.y[3]]) + " + "
                    trace.hovertext = trace.hovertext.rstrip('+ ')
                    # Check if cluster has only 2 children
                    if len(trace.hovertext.split(" + ")) < 2 and len(tmp.split("+"))-1 > 0:
                        trace.hovertext +=  ' and ' + tmp.rstrip('+ ')
                    if len(trace.hovertext.split(" + ")) > 2:
                        cls = [i.replace('cluster', '').strip() for i in trace.hovertext.split('+')] # cluster ids
                        rls = [i for i in cls if row_clusters[i][4] < trace.x[1]] # cluster x position
                        cls = [i for i in cls if i not in rls]
                        while len(cls) > 2:
                            vls = [row_clusters[i][4] for i in cls] # cluster x position
                            idx = (np.abs(np.asarray(vls) - trace.x[1])).argmax()
                            cls.pop(idx)
                        trace.hovertext = "cluster " + cls[0] + " + " + "cluster " + cls[1]
                    row_clusters[trace.text][2] = trace.hovertext.replace(' and', ',').replace(' +', ',')                                  
                trace.hovertext = '<b>' + trace.name + ' merges:</b><br>' + trace.hovertext
                trace.hovertemplate = trace.hovertext + '<extra><b>dendrogram Y</b><br>' + trace.name + '</extra>'

            elif trace.name.startswith("Col"):   # X-dendrograms
                if row_prefix != '':
                    trace.name = trace.name.replace('Col Cluster', col_prefix)
                trace.xaxis = 'x1'
                trace.yaxis = 'y3'
                xticks_dict = dict(zip(xtick_vals, xtick_labs))
                if trace.x[0] in xticks_dict and trace.x[3] in xticks_dict:
                    trace.hovertext = str(xticks_dict[trace.x[0]]) + " and " + str(xticks_dict[trace.x[3]])
                    col_clusters[trace.text][2] = trace.hovertext.replace(' and', ',')                    
                else:
                    tmp = ''
                    for c in col_clusters:
                        if c != trace.text:
                            diff = col_clusters[c][1] - (col_clusters[c][1] - col_clusters[c][0])/2
                            if trace.x[3] == diff:   
                                trace.hovertext += "cluster " + c + " + "
                                if trace.x[0] in xticks_dict:
                                    tmp += str(xticks_dict[trace.x[0]]) + " + "
                            elif trace.x[0] == diff:
                                trace.hovertext += "cluster " + c + " + "
                                if trace.x[3] in xticks_dict:
                                    tmp += str(xticks_dict[trace.x[3]]) + " + "
                    trace.hovertext = trace.hovertext.rstrip('+ ')
                    # Check if cluster has only 2 children
                    if len(trace.hovertext.split(" + ")) < 2 and len(tmp.split("+"))-1 > 0:
                        trace.hovertext +=  ' and ' + tmp.rstrip('+ ')
                    if len(trace.hovertext.split(" + ")) > 2:
                        cls = [i.replace('cluster', '').strip() for i in trace.hovertext.split('+')] # cluster ids
                        rls = [i for i in cls if col_clusters[i][4] < trace.y[1]] # cluster x position
                        cls = [i for i in cls if i not in rls]
                        while len(cls) > 2:
                            vls = [col_clusters[i][4] for i in cls] # cluster x position
                            idx = (np.abs(np.asarray(vls) - trace.y[1])).argmax()
                            cls.pop(idx)
                        trace.hovertext = "cluster " + cls[0] + " + " + "cluster " + cls[1]
                    col_clusters[trace.text][2] = trace.hovertext.replace(' and', ',').replace(' +', ',')
                trace.hovertext = '<b>' + trace.name + ' merges:</b><br>' + trace.hovertext
                trace.hovertemplate = trace.hovertext + '<extra><b>dendrogram X</b><br>' + trace.name + '</extra>'
print("Dendrogram data prepared.")

# %%
# Prepare data for Y-dendrogram interactive labels and ranges for Y-bars
row_content = {}                # all elements for a given cluster
cluster_range = {}              # real ranges for a given cluster
for c in row_clusters.keys():
    row_content[c] = row_clusters[c][2]
    cluster_range[c] = [row_clusters[c][0], row_clusters[c][1]]
    tokens = [j.strip() for j in row_clusters[c][2].split(',')]
    to_remove = []
    for i in tokens:
        if i.startswith('cluster'):
            c_id = i.replace('cluster', '').strip()
            news = [j.strip() for j in row_clusters[c_id][2].split(',')]
            tokens.extend(news)
            to_remove.append(i)
    for j in to_remove:
        tokens.remove(j)
    ranges = sum([[key for key, val in yticks_dict.items() if val == element] for element in tokens], [])
    cluster_range[c] = [min(ranges) - (0.03*y_step), max(ranges) + (0.03*y_step)]
    tokens = [i+", " for i in tokens]
    if len(tokens) > n_per_line_row:
        i = n_per_line_row - 1
        while i < len(tokens):
            tokens[i] += '<br>'
            i += n_per_line_row
    row_content[c] = str(''.join(tokens)).strip().rstrip(',').rstrip(', <br>')

print("Y-dendrogram interactive labels prepared.")

# %%
# Prepare data for X-dendrogram interactive labels and ranges for X-bars
col_range = {}              # real ranges for a given cluster
for c in col_clusters.keys():
    col_range[c] = [col_clusters[c][0], col_clusters[c][1]]
    tokens = [j.strip() for j in col_clusters[c][2].split(',')]
    to_remove = []
    for i in tokens:
        if i.startswith('cluster'):
            c_id = i.replace('cluster', '').strip()
            news = [j.strip() for j in col_clusters[c_id][2].split(',')]
            tokens.extend(news)
            to_remove.append(i)
    for j in to_remove:
        tokens.remove(j)
    ranges = sum([[key for key, val in xticks_dict.items() if val == element] for element in tokens], [])
    col_range[c] = [min(ranges) - (0.01*y_step), max(ranges) + (0.01*y_step)]

print("X-dendrogram interactive labels prepared.")

# %%
# Adjust dendrograms and bars traces
for idx, trace in enumerate(fig["data"]):
    if trace.type == 'scatter':
        # List all elements grouped in a given cluster (Y dendrogram)
        if trace.name != None and list_all_row:
            if trace.name.startswith("Row") or trace.name.startswith(row_prefix):    # Y dendrogram
                trace.hovertext += '<br><br>' + "cluster size: " + str(len(row_content[trace.text].split(','))) + "<br>" + row_content[trace.text]
                trace.hovertemplate = trace.hovertext + '<extra><b>dendrogram Y</b><br>' + trace.name + '</extra>'

        # Adjust cluster bars (update real length and trace color)
        else:
            if trace.x == (0,0):                 # Y-bars
                trace.xaxis = 'x2'
                trace.yaxis = 'y1'
                trace.hoverinfo = 'text+name'
                for i in row_markers:
                    gid = str(i['group'])
                    if list(trace.y) == [row_clusters[gid][0], row_clusters[gid][1]]:
                        trace.name = "merged cluster " + gid
                        trace.y = cluster_range[gid]
                        trace.text = '<b>merged cluster: ' + gid + '</b><br>' + str(i['annotation'])
                        if i['color'] == 'white':
                            trace.line['color'] = row_clusters[gid][3]
                trace.hovertemplate = trace.text + '<extra><b>bar cluster Y</b><br>' + trace.name + '</extra>'
            
            elif trace.y == (0,0):               # X-bars
                trace.xaxis = 'x1'
                trace.yaxis = 'y2'
                trace.hoverinfo = 'text+name'
                for i in col_markers:
                    gid = str(i['group'])
                    if list(trace.x) == [col_clusters[gid][0], col_clusters[gid][1]]:
                        trace.name = "merged cluster " + gid
                        trace.x = col_range[gid]
                        trace.text = '<b>merged cluster: ' + gid + '</b><br>' + str(i['annotation'])
                        if i['color'] == 'white':
                            trace.line['color'] = col_clusters[gid][3]
                trace.hovertemplate = trace.text + '<extra><b>bar cluster X</b><br>' + trace.name + '</extra>'
                
print("Adjusted dendrograms and bars traces.")

# %%
# Clean Layout from redundant axis objects and annotations
fig.layout.annotations = []
for i in fig.layout:
    if i.startswith('xaxis'):
        fig.layout.pop(i, None)
    if i.startswith('yaxis'):
        fig.layout.pop(i, None)

# Prepare margins
graph_margins = {}
if margins[0] != 'd':
    graph_margins['l'] = margins[0]  
if margins[1] != 'd':
    graph_margins['t'] = margins[1]
if margins[2] != 'd':
    graph_margins['r'] = margins[2] 
if margins[3] != 'd':
    graph_margins['b'] = margins[3] 
        
# Update the Layout settings
fig.update_layout(
    # General settings
    height=graph_height, width=graph_width, margin=graph_margins,
    paper_bgcolor=graph_bg_color,
    plot_bgcolor=drawing_bg_color,
    font=dict(family=font_family),
    # Title, Legend, Axes
    title=dict(text=graph_title, font=dict(color=ti_color, size=ti_size), x=ti_x, y=ti_y),
    showlegend=is_legend, legend = dict(x=legend_x, y=legend_y),
    xaxis1=dict(title=dict(text=x_title, font=dict(color=x_ti_color, size=x_ti_size)),                                  # heatmap, horizontal (cols): bars, dendro
                range = x_range, domain=[dendro_ratio[1],1], side=x_tick_lab_side,
                showline=x_axis_show, linewidth=x_axis_width, linecolor=x_axis_color, mirror=x_axis_mirror, 
                ticks=x_axis_ticks, tickwidth=x_tick_width, ticklen=x_tick_len, tickcolor=x_tick_color,
                showticklabels=show_xtick_lab, tickangle=x_tick_lab_angle, 
                tickmode='array', tickvals=xtick_vals, ticktext=xtick_labs, 
                tickfont=dict(color=x_tick_lab_color, size=x_tick_lab_size),
               ),
    xaxis2=dict(domain=[dendro_ratio[1]*dendro_factor,dendro_ratio[1]], showticklabels=False),                          # vertical bars
    xaxis3=dict(domain=[0,dendro_ratio[1]*dendro_factor], showticklabels=False),                                        # vertical dendro
    yaxis1=dict(title=dict(text="", font=dict(color=y_ti_color, size=y_ti_size)),                                       # heatmap, vertical (rows): bars, dendro
                range=y_zoom, domain=[0,1-dendro_ratio[0]], side=y_tick_lab_side,
                showline=y_axis_show, linewidth=y_axis_width, linecolor=y_axis_color, mirror=y_axis_mirror,
                ticks=y_axis_ticks, tickwidth=y_tick_width, ticklen=y_tick_len, tickcolor=y_tick_color,
                showticklabels=show_ytick_lab, tickangle=y_tick_lab_angle, fixedrange=False,
                tickfont=dict(color=y_tick_lab_color, size=y_tick_lab_size),
               ),
    yaxis2=dict(domain=[1-dendro_ratio[0],1-dendro_ratio[0]*dendro_factor*0.8], showticklabels=False),                  # horizontal bars
    yaxis3=dict(domain=[1-dendro_ratio[0]*dendro_factor*0.8,1], showticklabels=False),                                  # horizontal dendro
    # Interactive hover labels
    hoverlabel=dict(namelength = -1, align=hover_align, font=dict(size=hover_size)),
)

# Update Heatmap Y axis ticks if 'text' labels are provided
if y_ticks_str:
    fig.update_layout(
        yaxis1=dict(tickmode = 'array', tickvals = ytick_vals, ticktext = ytick_labs, fixedrange = True, range=y_zoom,) 
    )
    
fig.add_annotation(x=y_ti_x, y=y_ti_y, showarrow=False, xref='paper', yref='paper',                                     # customized title of Y axis
        text=y_title, textangle=y_ti_angle, font=dict(color=y_ti_color, size=y_ti_size),
)


fig.show(config=config)              # to display graph interally in the notebook

# %% [markdown]
# ## 6. Export interactive HTML chart and/or Write static image file
# A refined chart can be exported in many different ways.
# * First, you can use the built-in options bar, located directly above the interactive chart. There, using the camera icon, you can download a static image in the format and size defined in config.
# * You can also export a static image in any format (vector or raster) directly from the command line (see the code cell below).
# * Also, you can export the interactive chart as HTML and even have it open immediately in a new browser tab.
#
# *<span style="color:gray">If you want to export the image, remove the **'#'** tag in the selected row of code below. <br>Then run the cell again (`ctrl+enter`). <br>If you observe an error, you have probably not installed the kaleido package yet. Quick fix: `pip install -U kaleido`.</span>*

# %%
print("Static image saved to: " + static_img_filename + '.' + static_img_format)
fig.write_image(static_img_filename + '.' + static_img_format)          # static image exported in the selected format
fig.write_html(static_img_filename + '.html', auto_open=html_auto)      # interactive HTML chart (opens automatically in the new browser tab)

# %% [markdown]
# ## Static image of the graph
#
# *(Please edit this markdown cell and provide the name of the desired static image file.)*
#
# ![PC1 vs PC2](example_clustergram.png)
